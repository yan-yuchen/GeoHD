# %% [markdown]
# # Guide to Using Test Functions
#
# This document aims to guide users on how to use the test functions in the GeoHD package to ensure code correctness.
#
# ## Preparation
#
# Before using the test functions, make sure you have installed the GeoHD package and have the necessary test data.
#
# Please execute the test commands in order, as some of the test commands may require the output of the previous step.

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# %run visualize_shapefile_test.py
# Out:
# Folder 'output' already exists.
# First few rows of point data:
#    pointid  grid_code                    geometry
# 0        1          0  POINT (-74.08891 40.64669)
# 1        2          0  POINT (-74.08145 40.64601)
# 2        3          0  POINT (-74.10463 40.64526)
# 3        4          0  POINT (-74.07705 40.64472)
# 4        5          0  POINT (-74.09780 40.64465)
# Visualization image saved at: ./output/custom_image.png

# %%
# %run plot_g_function_test.py
# Out:
# Folder 'output' already exists.

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# %run grid_visualization_test.py
# Out:
# Folder 'output' already exists.

# %%
# %run plot_density_raster_test.py
# Out:
# Folder 'output' already exists.
# Density data saved at: ./output/density_data.npy

# %%
# %run adaptive_kde_test.py
# Out:
# Folder 'output' already exists.
# Initial bandwidth (h): 0.009043640362592052
# totally cost 2.190000534057617
# the parameter of h:0.00859145834446245,the parameter of a:0.3375
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Density data saved at: ./output/AKDE_density_data.npy

# %%
# %run extract_hotspots_test.py
# Out:
# Folder 'output' already exists.
